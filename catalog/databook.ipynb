# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from operator import index


index_cols = ['index', 'ບໍລິສັດ', 'No', 'ຊື່ຜະລິດຕະພັນ', 'ຂະຫນາດມັດຫໍ່','Location imge', 'ຮູບພາບ', 'ສ່ວນປະກອບ', 'ສັບພະຄຸນ', 'ຊະນິດຢາ', 'ປະເພດ']
col_use = ['index', 'ບໍລິສັດ', 'ຊື່ຜະລິດຕະພັນ', 'Location imge', 'ຮູບພາບ','ຊະນິດຢາ', 'ປະເພດ']
df=pd.read_excel('ຈັດໝວດຢາCBF.xlsx', usecols=col_use,)
df
# Out:
#      index  ບໍລິສັດ     ຊື່ຜະລິດຕະພັນ  \
# 0        0  ຊີບີເອບ        D-5-W CBF
# 1        1  ຊີບີເອບ       D-10-W CBF
# 2        2  ຊີບີເອບ     D-5-1/2S CBF
# 3        3  ຊີບີເອບ     D-5-1/2S CBF
# 4        4  ຊີບີເອບ         D-5-S CBF
# ..     ...      ...               ...
# 111    112  ຊີບີເອບ          METYLEN
# 112    113  ຊີບີເອບ     PETADINE 10%
# 113    114  ຊີບີເອບ     PETADINE 10%
# 114    115  ຊີບີເອບ         AQUA CBF
# 115    116  ຊີບີເອບ  DISTILLED WATER
#
#                                          Location imge  ຮູບພາບ  \
# 0    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 1    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 2    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 3    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 4    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# ..                                                 ...     ...
# 111  https://raw.githubusercontent.com/maithaen/-/m...     NaN
# ...
