# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_name = 'ຈັດໝວດຢາCBF.xlsx'
index_cols = ['index', 'ບໍລິສັດ', 'No', 'ຊື່ຜະລິດຕະພັນ', 'ຂະຫນາດມັດຫໍ່','Location imge', 'ຮູບພາບ', 'ສ່ວນປະກອບ', 'ສັບພະຄຸນ', 'ຊະນິດຢາ', 'ປະເພດ', 'ລາຄາ', 'select row']
col_use = ['index', 'ບໍລິສັດ', 'ຊື່ຜະລິດຕະພັນ', 'Location imge', 'ຮູບພາບ','ຊະນິດຢາ', 'ປະເພດ','ລາຄາ','select row']
df=pd.read_excel(data_name, usecols=col_use, sheet_name='Sheet2')
df
# Out:
#      index  ບໍລິສັດ             ຊື່ຜະລິດຕະພັນ  \
# 0       16  ຊີບີເອບ                AMOXIN 125
# 1       17  ຊີບີເອບ      AMOXYCILINE-DRY 250
# 2       21  ຊີບີເອບ              AMPICIN.DRY
# 3       23  ຊີບີເອບ       PENICIN 100.000 UI
# 4       24  ຊີບີເອບ  PENICILLIN V 200.000 UI
# ..     ...      ...                       ...
# 112     97  ຊີບີເອບ                    FOLIC
# 113     98  ຊີບີເອບ                 NEUROBIT
# 114     99  ຊີບີເອບ            NEUROBIT FORT
# 115    100  ຊີບີເອບ                VITA C 50
# 116    101     ເລກ2                       NaN
#
#                                          Location imge  ຮູບພາບ  \
# 0    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 1    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 2    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 3    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 4    https://raw.githubusercontent.com/maithaen/-/m...     NaN
# ..                                                 ...     ...
# 112  https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 113  https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 114  https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 115  https://raw.githubusercontent.com/maithaen/-/m...     NaN
# 116                                                NaN     NaN
#
#                      ຊະນິດຢາ                         ປະເພດ  ລາຄາ  select row
# 0                Anti-Biotic  Dry Powder&Syrup&Subspension   NaN         1.0
# 1                Anti-Biotic  Dry Powder&Syrup&Subspension   NaN         1.0
# 2                Anti-Biotic  Dry Powder&Syrup&Subspension   NaN         1.0
# 3                Anti-Biotic  Dry Powder&Syrup&Subspension   NaN         0.0
# 4                Anti-Biotic  Dry Powder&Syrup&Subspension   NaN         0.0
# ..                       ...                           ...   ...         ...
# 112  Vitaminnes and minerals            Tablets & Capsules   NaN         1.0
# 113  Vitaminnes and minerals            Tablets & Capsules   NaN         1.0
# 114  Vitaminnes and minerals            Tablets & Capsules   NaN         1.0
# 115  Vitaminnes and minerals            Tablets & Capsules   NaN         1.0
# 116                      NaN                           NaN   NaN         NaN
#
# [117 rows x 9 columns]
