# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_name = 'ຈັດໝວດຢາCBF.xlsx'
index_cols = ['index', 'ບໍລິສັດ', 'No', 'ຊື່ຜະລິດຕະພັນ', 'ຂະຫນາດມັດຫໍ່','Location imge', 'ຮູບພາບ', 'ສ່ວນປະກອບ', 'ສັບພະຄຸນ', 'ຊະນິດຢາ', 'ປະເພດ', 'ລາຄາ', 'select row']
col_use = ['index', 'ບໍລິສັດ', 'ຊື່ຜະລິດຕະພັນ', 'Location imge', 'ຮູບພາບ','ຊະນິດຢາ', 'ປະເພດ','ລາຄາ','select row']
df=pd.read_excel(data_name, usecols=col_use, sheet_name='Sheet2')
df
# Out:
#      index  ບໍລິສັດ             ຊື່ຜະລິດຕະພັນ  \
# 0     16.0  ຊີບີເອບ                AMOXIN 125
# 1     17.0  ຊີບີເອບ      AMOXYCILINE-DRY 250
# 2     21.0  ຊີບີເອບ              AMPICIN.DRY
# 3     23.0  ຊີບີເອບ       PENICIN 100.000 UI
# 4     24.0  ຊີບີເອບ  PENICILLIN V 200.000 UI
# ..     ...      ...                       ...
# 131    NaN     ເລກ3              Berber 60 ml
# 132    NaN     ເລກ3             Dechoiest Tea
# 133    NaN     ເລກ3        Vitamin C 500mg BT
# 134    NaN     ເລກ3                 Di-Vormin
# 135    NaN     ເລກ3         AZITHROMAX 500 mg
#
#                                          Location imge  ຮູບພາບ      ຊະນິດຢາ  \
# 0    https://raw.githubusercontent.com/maithaen/-/m...     NaN  Anti-Biotic
# 1    https://raw.githubusercontent.com/maithaen/-/m...     NaN  Anti-Biotic
# 2    https://raw.githubusercontent.com/maithaen/-/m...     NaN  Anti-Biotic
# 3    https://raw.githubusercontent.com/maithaen/-/m...     NaN  Anti-Biotic
# ...
